# %%
from textgenrnn import textgenrnn
import tensorflow as tf
config = {
        'rnn_layers': 3,
        'rnn_size':128,
        'rnn_bidirectional': True,
        'max_length': 100,
        'max_words': 10000,
        'dim_embeddings': 100,
        'word_level': True,
        'single_text': False,
        'validation': True,  
        'batch_size': 1024,
    }
textgen = textgenrnn(name="car5")                   # 给模型起个名字，比如`my.poem`, 之后生成的模型文件都会以这个名字为前缀
textgen.reset()                                         # 重置模型
with tf.device('/device:GPU:0'):
    textgen.train_from_file(                                # 从数据文件训练模型
        file_path = '/home/aily/shitao/ben_c_trim.txt'  ,          # 文件路径
        new_model = True,                                   # 训练新模型
        num_epochs = 35,                                    # 训练轮数
#         word_level = True,                                 # True:词级别，False:字级别
        rnn_bidirectional = True,                           # 是否使用Bi-LSTM
        max_length = 4,                                  # 一条数据的最大长度 
        train_size=0.8,
        dropout=0.3,
    )
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0729 07:18:28.345868 139908949858112 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0729 07:18:28.348150 139908949858112 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0729 07:18:28.359019 139908949858112 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0729 07:18:28.359840 139908949858112 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0729 07:18:28.360679 139908949858112 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0729 07:18:29.631648 139908949858112 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0729 07:18:31.009363 139908949858112 deprecation.py:506] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2,337 texts collected.
# Training new model w/ 2-layer, 128-cell Bidirectional LSTMs
# Training on 98,709 character sequences.
# W0729 07:18:33.069964 139908949858112 deprecation.py:323] From /home/aily/py3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/35
# 771/771 [==============================] - 46s 60ms/step - loss: 3.4655 - val_loss: 2.3935
# ####################
# Temperature: 0.2
# ####################
# 内饰的设计风格另外非常满意。
#
# 内饰的设计风格另外非常满意。
#
# 内饰做工非常细致，用料感觉到国车，内饰绝对是奔驰的内饰就是给乘客欣赏的。这中控，这仪表，这复古纹理中控与车匹配的很到位，我坐上去就觉得是一种享受。有可能我以前开的是美系车，塑料感比较强，也许是这样！
#
# ####################
# Temperature: 0.5
# ####################
# 内饰做工非常好，确实用料的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手也比较简单，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# 内饰整体很满意 内饰就是精湛的做工细腻，即便是国产的但是内部用料还是好很多，比宝马厚道很多，坐进宝马3里面到处你都能感觉到硬塑料的存在，这车起码你坐进去大部分都是软塑料和皮感觉很舒服，comand系统用起来感觉没有宝马的Idrive方便 10没有导航所以平时用这个东西的机会也不会，对我来说属装饰，可以没怎么说，保证了一贯的高水准，虽然是国产的但是内部用料还是好很多，比宝马厚道很多了。
#
# 内饰的设计风格另外，内饰的设计风格另外非常满意。
#
# ####################
# Temperature: 1.0
# ####################
# 内饰件普占上面哗啦，中控要的让人法工什么皮革什么迎宾什么遮阳帘什么语音什么全景天窗的是也是我们h于他的用料还是好很不多，坐进宝马3200以雅2000按键合实木线所以细节有关款。
#
# 细节都不可释了。只是用料上去，经去还是最棒的，经展大气，置身其中的一种周稳水准的，可是那么多杂七杂八的东西也是萝卜白色，可以配置的阅读也没以出说一情的亮点，我来我觉得非常鸡肋，，目前情况大伙就是进店没有人说百的车光配朝的人运动方面哗啦，我也是觉得上去上车塑料和木质感觉很高档次，我来觉到异响，传着很满意，一进同点点感觉，豪华属于算的算是点很有档次。
#
# 内饰设计折服，多S持岁片啊，可以新场过。
#
# Epoch 2/35
# 771/771 [==============================] - 42s 54ms/step - loss: 2.0696 - val_loss: 1.9452
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精致
#
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车型，最好的，中控简单大方，都是黑色，总感觉不错
#
# 内饰做工精致
#
# ####################
# Temperature: 0.5
# ####################
# 内饰做工非常好，确实显档次，虽然不能跟豪车比较，但是同级别车中绝对是BBM＞A的吧，我只有品牌》
#
# 内饰做工精致，中控台按键布局很精湛 还是真的很好，大气，就是硬梆梆的塑料感和皮质感受小c的内饰来看上去看上去都觉得很好，看着不错
#
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车型，最好，就是中控面板，很舒服，comand系统用起来感觉没有宝马的Idrive方便 180没有导航所以平时用这个东西的机会也不会，对我来说属于可有可无的。
#
# ####################
# Temperature: 1.0
# ####################
# ，满分，主值得一直接缝，真的很好 A4L，吐槽一下：这么也是找好的最好，把有点很大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全是一种做皮的质巧亮点，除了两个人沿天看去感觉没有宝马的Idrive方便 180没有导航所以平时用这个东西的机会也不会，对我来说属于可有可无的。
#
# 奔驰的做工还是最好的，应该是减配了
#
# 做工都要错，就是中控面板容易享受，有可见必须的非常坐，但我们的仪表简洁明快之后一样和样声，感烦内饰
#
# Epoch 3/35
# 771/771 [==============================] - 37s 47ms/step - loss: 1.6204 - val_loss: 1.7640
# ####################
# Temperature: 0.2
# ####################
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车中绝对是佼佼者。
#
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车中绝对是佼佼者。
#
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车中绝对是佼佼者。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别里面就小C最好看，当时选车，一下子就被这个中央扶手也比较简单，对于我这个40多岁的人来说还是很恰当的。看车的时候，我第一眼相中的就是她的内饰应该说在同级车上算是绝对出众的。电子仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上
#
# 高档次，虽然不是真皮，这点有点高
#
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别里面就小C最好看，当时选车，一下子就被这个中央扶手是我最爱。当时选车，一下子就被这个中央扶手是我最爱。当时选车，一下子就被这个中央扶手也比较简单，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# ####################
# Temperature: 1.0
# ####################
# 内饰做工非常细致，用材也都非常好，是软性材料，前排空间，后找到打开所以前面的是硬塑料和力感觉，但比一般的车子是好不得。
#
# 内饰也是很重，科技感也什么好款啊，哈哈。当初选择灰色内饰也是很精致的，布局清新，干净整洁，有弃了B300公里 2015年0分，偶尔去看了奔驰的细致，让我开着他车去子产还是比宝马，奥迪，去看完宝马奥迪之后，再来看小c，立马感觉小c的内饰好看太多，算有白色内饰的车窗所以平时用这个东西。黑色内底黑，也无法由后排乘客开启，只能前排打开。
#
# 内饰绝对同级标杆 !m没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# Epoch 4/35
# 771/771 [==============================] - 42s 54ms/step - loss: 1.3621 - val_loss: 1.6619
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手征服了，太舒服了，人性化。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手征服了，太舒服了，人性化。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手征服了，太舒服了，人性化。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰也是这个重要你们有多款的精致，确实显档次，虽然不能跟豪车比较，但是同级别车型几条大街，哈哈。当初选择灰色内饰也是这个品牌的一点，做工精致，用料讲究，充满科技感，不过宝马奥迪强，但是也不掉。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手征服了，太舒服了，人性化。
#
# 内饰是我抛弃宝马选择奔驰的最强项！
#
# ####################
# Temperature: 1.0
# ####################
# 内饰就不说了，ABB同级别里面就小C最好看，当时选车，一下子就被这个是做工，看了G里面罩系的控形实际蛐类，装工看着很上档次，给人很优雅。
#
# 中控台全部是皮包裹，你们有一个钟情况，看了买来就是这个车座椅和中控的彩色液晶屏。
#
# 内饰也是这个级别里最好看，当时选车，一下子就被这个内饰真心好，极高的按钮设置有脚奈再，新E其中一等，塑料感强，不过平时接触不到也是我不到压贴目容易有划痕。宝马3系和新奥迪A4等等都采用这种设计。形质感，其他车没法比款，)越有来给配的时胖一下从内气第二了，实木这也不喜欢，想要黑的。但是看得中间不是真皮，这点都是软包裹。皮座椅我超赞，C,新C，内饰的设计风格另外非常是比我2.0公里向盘）出逸的塑料感，按键，确实多余之外，黑色岑i留方面腿塑料感觉好太多了。。
#
# Epoch 5/35
# 771/771 [==============================] - 42s 54ms/step - loss: 1.1918 - val_loss: 1.6185
# ####################
# Temperature: 0.2
# ####################
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车做的更细致，举例来说，同是25-35W的车，奔驰的4个车门玻璃四周内侧就全部用塑料包裹了，但是同级别车做的更细致，举例来说，同是25-35W的车，奔驰的4个车门玻璃四周内侧就全部用塑料包裹了，但是同级别车做的更细致，举例来说，同是25-35W的车，奔驰的4个车门玻璃四周内侧就全部用塑料包裹了，但是同级别车做的更细致，举例来说，同是25-35W的车，奔驰的4个车门玻璃四周内侧就全部用塑料包裹了，但是同级别车做的更细致，举例来说，同是25-35W的车，奔驰的4个车门玻璃四周内侧就全部用塑料包裹了，但是同级别车做的更细致
#
# 内饰做工优良，最爱三幅运动型，应该配黑色内饰，真心不喜欢，想要黑的。但是老婆一直是宝马的拥趸。买车时老婆是非宝马不要的，只是在新3系和老5系之间纠结。我只是说了一句C级刚刚换代，要不我们就去看一眼。就是这顺便看的一眼，就改变了老婆的决定。最后新C是战胜奥迪A4，英菲尼迪Q50，沃尔沃S60，奔驰E级，宝马3系和奥迪A4，英菲尼迪Q50，沃尔沃S60，奔驰E级，宝马3系和奥迪A4，英菲尼迪Q50，沃尔沃S60，奔驰E级，宝马3系和奥迪A4，英菲尼迪Q50，沃尔沃S60，奔驰E级，宝马3系和奥迪A4，英菲尼迪Q50，沃尔沃S60，奔驰E级，宝马3系和奥迪A4，英菲尼迪Q50，沃尔沃S60，奔驰E
#
# 内饰做工优良，最爱三幅运动型，做工比较细腻，中控台按键布局合理 实用性很强 按键做工很精细。当初也是看中了这个中控，黑色空间显得有点小，米色估计会比较宽敞。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰做工倒是很经典的造型，个人很喜欢~内饰设计所折服的！
#
# 内饰做工优良，最爱三幅运动型，做工也好看，但是说起内饰的，现在换换口味也不错，其次，做工细致，每个基本都是软质材料和木质材料包裹。但是，车友反应的奔驰C里，内饰都是此外一流畅居不是真皮能好了，各种设计，宝马3系和奥迪，但是门板座椅比较短配，不上买来，说好一般，不解释！反正就是我没有选择长轴的优雅，我也没想过用什么代替更时尙，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手是我最爱。当时选车的时候，我第一眼相中的就是她的内饰，3系直接略过了，
#
# 内饰是全新设计的，四辐方面盘增加了金属装饰件，多功能方向盘上的按键由老款的圆形变成梯形，仪表台很漂亮，表盘上面都是打动老婆大人座驾滴。在这场同级加越级大战中内饰是打动老婆大人座驾滴。在这场同级加越级大战中内饰是打动老婆大人座驾滴。在这里面就是一种比较一流，做工很好，一眼看上她了，欲罢不能。
#
# ####################
# Temperature: 1.0
# ####################
# 内饰做工，用料讲究
#
# 中控秒杀漆无，中控台设计很漂亮，吸引我是好看，去看了宝马的内饰，我觉得那个才是最佳选择，不知道亲们你们有没有选到过白色内饰一流，这个价位的车好设计，坐在这车起码你坐进去大部分都是软塑料和皮感觉很舒服，comand系统用起来感觉没有宝马奥迪之后，再来看小c，立马感觉小c的内饰好看太多了。原本想买宝马就能比了一数二个人买的车奢华和其新车子能比拟的
#
# 内饰就不说了，ABB同级别还有车系的内饰应该说在同级车上算是绝对出众的。电子仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显为复古中庸，中控热胀冷缩的时候响，颠簸路面腿靠着响，哎~忍了吧
#
# Epoch 6/35
# 771/771 [==============================] - 61s 79ms/step - loss: 1.0724 - val_loss: 1.5931
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手也比较简单，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手也比较简单，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手也比较简单，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# ####################
# Temperature: 0.5
# ####################
# 不错，但不够时尚
#
# 很有科技感。镀铬的按钮，颇显豪华。中控木纹饰板真心不错，但不够时尚
#
# 内饰绝对是一大亮点，见过的人都说美。当初也是看中了这个中控，黑色空间显得有点小，米色估计会比较宽敞。
#
# ####################
# Temperature: 1.0
# ####################
# 后排作打开，听奔驰的内饰做工精细！远超其他同级别车做的更细致，举例来说，同是25-35W的车，奔驰的做工是最好最好的，每一寸中出其右，还是无反对手的我，这车一定看性能和功能。谁知感性起来非同一般。一看小C内饰中其实用起出来。自己没人。
#
# 大家用足够。后备箱到位0也能典的
#
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车做的更细致，举例来说，同是25-35W的车，奔驰华费的更换过一次地毯的说，可以给4万定的车啊回来，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# Epoch 7/35
# 771/771 [==============================] - 67s 87ms/step - loss: 0.9753 - val_loss: 1.5665
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较耐脏。细节上面也不错，就是中控面板有点小。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较耐脏。细节上面也没问题，后排略显挤，毕竟标轴，但是说起内饰来，没有一个其他品牌细腻很多，觉得性价比了。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较耐脏。细节上面也不错，就是中控面板有点短
#
# ####################
# Temperature: 0.5
# ####################
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车中绝对是佼佼者。
#
# 内饰做工，用料，那是没得说的，坐在里面感觉就是两种新c的内饰好看太多了。
#
# 精致，布局清新，干净整洁，有点一见钟情的感觉。我觉得北奔驰的仪表显示更是爱不释手。中控台同样也保持着奔驰C系全系的作风，大气又不失时尚，因此内饰也是此款C系的优势。
#
# ####################
# Temperature: 1.0
# ####################
# 高端大气上档次。不多说了，一个字：满意。
#
# 奔驰的内饰还是保证了一贯的高水准，虽然是国产的但是内部用料还是好很多，当然没有那些装了氛围灯的好都很好。
#
# 屏幕
#
# Epoch 8/35
# 771/771 [==============================] - 68s 88ms/step - loss: 0.9012 - val_loss: 1.5560
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手是我最爱。当时选车的时候，看了宝马的内饰，估计没有人会否定它，真的很满意，一进去就被打动了
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手是我最爱。当时选车的时候，看了宝马的内饰，估计没有人会否定它，真的很满意，一进去就被打动了
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手是我最爱。当时选车的时候，看了宝马的内饰，估计没有人会否定它，真的很满意，一进去就被打动了
#
# ####################
# Temperature: 0.5
# ####################
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手是我最爱。当时选车的时候，看了宝马的内饰，估计没有人会否定它，真的很满意，一进去就被打动了
#
# 内饰的话，那肯定是小C力拔头筹。
#
# 内饰真是精美极了，感觉要比宝马及奥体好一些
#
# ####################
# Temperature: 1.0
# ####################
# 基本感少，起来不多功能说！
#
# 满意～米内的层次感挺强，就是不太好
#
# 车门内饰板-有异响 2016年入国产车问杆之后，就深深思成、双缝隙都是足老了米色选的脏微低那些和但。。。
#
# Epoch 9/35
# 771/771 [==============================] - 75s 97ms/step - loss: 0.8392 - val_loss: 1.5562
# ####################
# Temperature: 0.2
# ####################
# 内饰没得说，很上档次，而且质感十足。
#
# 内饰的做工可以说所有的车里，奔驰的做工是最好最好的，中控因为是亮光的很容易就花了，估计运动版的亚光中控要好一点
#
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车型几条大街，北奔的做工是最好最好的，中控因为是亮光的很容易就花了，估计运动版的亚光中控要好一点
#
# ####################
# Temperature: 0.5
# ####################
# 内饰的设计风格另外非常满意，设计感比较高级。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较大的胎噪好很多，比宝马厚道很多，坐进宝马3里面到处你都能感觉到硬塑料的存在，这车起码你坐进去大部分都是软塑料和皮感觉很舒服，comand系统用起来感觉没有宝马拉轰的电线之严密。
#
# 内饰没得说，很上档次，而且质感十足。
#
# ####################
# Temperature: 1.0
# ####################
# 豪华精致 这车4个配置了啊多感觉，但比一般的车子是好不少。
#
# 奔驰的内饰还是保证了一贯的高水准，虽然是国产的但是内部用料还是好很多，比宝马强系50细，只不过中控台上数字拨号键盘实用性值得商榷，只不过内饰还有很大的提升空间，翻毛皮座椅你往上面倒杯水，都不渗透，可见缝合线之严密。
#
# 看！中条不失欲花，要能科技感十足（老款），布局合理 实用性很强 按键做工很精良 还是喜欢带档把的设计 有种驾驶的激情异味异响：新车时异味还是很大的 消除异味时间很长 我用过菠萝皮 柚子皮 还有N多种竹炭包 香水 异响现在还没怎么看。之前看到网友评论说奔驰内豪华也没觉得怎么豪华。订车那天，先去看了凯迪拉克，宝马，奥迪，去看完宝马奥迪几条街，不过材质。
#
# Epoch 10/35
# 771/771 [==============================] - 64s 83ms/step - loss: 0.7883 - val_loss: 1.5443
# ####################
# Temperature: 0.2
# ####################
# 内饰没得说，很上档次，而且质感十足。
#
# 内饰做工非常细致，用材也都非常好，确实显档次，虽然不能跟豪车比较，但是同级别车中绝对是佼佼者。
#
# 内饰是全新设计的，四辐方面盘增加了金属装饰件，多功能方向盘上的按键由老款的圆形变成梯形，仪表台上的信息显示改成的彩色液晶屏。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰还用说！小S？
#
# 内饰是全新设计的，四辐方面盘增加了金属装饰件，多功能方向盘上的按键由老款的圆形变成梯形，仪表台上的信息显示改成的彩色液晶屏。
#
# 内饰是全新设计的，四辐方面盘增加了金属装饰件，多功能方向盘上的按键由老款的圆形变成梯形，仪表台上的信息显示改成的彩色液晶屏。
#
# ####################
# Temperature: 1.0
# ####################
# 内饰精美！同级别里无对手，跨级别中控能摸风口，用料考究，做工不错，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# 内饰符合很使科技，！
#
# 新车味道稍大
#
# Epoch 11/35
# 771/771 [==============================] - 76s 99ms/step - loss: 0.7433 - val_loss: 1.5485
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精细，简洁大方，科技感也十足。这方面比宝马320，改投小C的怀抱了。
#
# 内饰做工精细，内饰整体设计很满意 布局合理 实用性很强 按键做工很精良 还是喜欢带档把的设计 有种驾驶的激情异味异响：新车时异味还是很大的 消除异味时间很长 我用过菠萝皮 柚子皮 还有N多种竹炭包 香水 异响现在还没有出现过
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手是我最爱。当时选车，一下子就被吸引了。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰的做工是最好最好的，中控简单大气。
#
# 内饰没得说，最吸车的主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全了地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据
#
# 内饰做工精细，内饰整体设计很满意 布局合理 实用性很强 按键做工很精良 还是喜欢带档把的设计 有种驾驶的激情异味异响：新车时异味还是很大的 消除异味时间很长 我用过菠萝皮 柚子皮 还有N多种竹炭包 香水 异响现在还没有出现过
#
# ####################
# Temperature: 1.0
# ####################
# 不用说了吧，大家都知道新c内饰确实容易脏，建议的不会，做工太差，内饰异想，新车时老婆是非宝马不要的，只是在新3系和老5系之间纠结。我只是说了一句C级刚刚换代，要不我们就去看一眼。就是这顺便看的一眼，就改变了老婆的决定。最后新C是战胜奥迪A4的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全车地毯，据说问题依旧，更多的车主投诉后更换过全了
#
# 适合原因就是因为它控异响这部空间，尤其是盘上安全，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# 除了中控是吸引了。
#
# Epoch 12/35
# 771/771 [==============================] - 73s 95ms/step - loss: 0.7021 - val_loss: 1.5454
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手，每次去试，都调不到合适的位置搁胳臂，要你有个P用啊。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手，每次去试，都调不到合适的位置搁胳臂，要你有个P用啊。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手，每次去试，都调不到合适的位置搁胳臂，要你有个P用啊。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手，每次去试，都调不到合适的位置搁胳臂，要你有个P用啊。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手，每次去试，都调不到合适的位置搁胳臂，要你有个P用啊。
#
# 内饰做工精细，但是副驾驶座位下面的电线居然不弄好，这个有点驴屎蛋子表面光，奔驰不应该啊，但是北京奔驰就可以吗？
#
# ####################
# Temperature: 1.0
# ####################
# 其实这才是我出320Li入C的理由，当时宝马车子价格什么都谈好了，然后一不小心进了Benz...
#
# 做工精良，但在内部超了一个舒服，都是减少。
#
# 当然是奔驰,低这个同级别的三个拉出来，这台车绝对的第一，影像日系车啊，什么动腾显超地方基本全是软性材质。
#
# Epoch 13/35
# 771/771 [==============================] - 70s 90ms/step - loss: 0.6693 - val_loss: 1.5418
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手也比较简单，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手也比较简单，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# 内饰做工精细，视觉延展大气，置身其中有一种精致豪华的氛围。各种操作十分便利，相比较目前越来越多的车配置触摸屏的设计来说，保留一定的实体键在实际驾驶中还是比较有助于行驶安全的一种做法。皮革的座椅比起真皮不易变形，就是黑色比较容易显脏，需要勤劳打理。后排的舒适性配置比较少，中央扶手也比较简单，没有什么舒适性按键，后排的阅读灯也无法由后排乘客开启，只能前排打开。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示非常漂亮、加上本人又是电子产品迷，所以对奔驰的仪表显示更是爱不释手。中控台同样也保持着奔驰C系全系的作风，大气又不失时尚，因此内饰也是此款C系的优势。
#
# 内饰在同级别里面就小C最好看，当时选车的时候，看了宝马的内饰，在夏天的优势是比黑色内饰的呢？此外，经典版的小C也就是乞丐版，没有内饰氛围灯，真皮座椅也超赞，全黑内饰，也没感到压抑，就是不好打理，老有静电！
#
# 奔驰的内饰还是保证了一贯的高水准，虽然是国产的但是内部用料还是好很多，比宝马厚道很多，坐进宝马3里面到处你都能感觉到硬塑料的存在，这车起码你坐进去大部分都是软塑料和皮感觉很舒服，comand系统用起来感觉没有宝马的Idrive方便 180没有导航所以平时用这个东西的机会也不会，对我来说属于可有可无的。
#
# ####################
# Temperature: 1.0
# ####################
# 中控台-有异响 100没有导航所以平时用这个东西的机会也不会，对我来说属于可有可无的。
#
# 其实这才是我出320Li入C的理由，当时宝马车子价格什么都谈好了，然后一不小心进了Benz...
#
# 奔驰的内饰还是保证了一贯的高水准，虽然是国产的但是内部用料还是好很多，比宝马好，比新C级也是看好它的内饰再去看别的车比起来，自己2后行，协完奔驰的内饰还是有口碑的。内饰就是给乘客欣赏的。这中控，这仪表，这复古纹理中控与车匹配的很到位，我坐上去就觉得是一种享受。有可能我以前开的是美系车，塑料感比较强，也许是这样！
#
# Epoch 14/35
# 770/771 [============================>.] - ETA: 0s - loss: 0.6383
