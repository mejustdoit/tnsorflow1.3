# %%
from textgenrnn import textgenrnn
import tensorflow as tf
import os
from tensorflow.python.client import device_lib
from tensorflow.contrib.compiler import xla

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "99"
 
if __name__ == "__main__":
    print(device_lib.list_local_devices())
# Out:
# Using TensorFlow backend.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 18426065332429347442
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4014293308963224725
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8695064602704750823
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
config = {
        'rnn_layers': 4,
        'rnn_size': 64,
        'rnn_bidirectional': False,
        'max_length': 25,
        'max_words': 1000,
        'dim_embeddings': 100,
        'word_level': False,
        'single_text': False,
        'validation': True,  
        'train_size': 0.8,
        'batch_size': 1024,
        'dropout': 0.2
    }

# %%
textgen = textgenrnn(name="car")                   # 给模型起个名字，比如`my.poem`, 之后生成的模型文件都会以这个名字为前缀
textgen.reset()                                         # 重置模型
textgen.train_from_file(                                # 从数据文件训练模型
    file_path = '/home/aily/shitao/data.txt'  ,          # 文件路径
    new_model = True,                                   # 训练新模型
    num_epochs = 30,                                    # 训练轮数
    word_level = False,                                 # True:词级别，False:字级别
    rnn_bidirectional = True,                           # 是否使用Bi-LSTM
    max_length = 25                                   # 一条数据的最大长度 
)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0729 07:22:22.651353 140097193137984 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0729 07:22:22.655007 140097193137984 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0729 07:22:22.687744 140097193137984 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0729 07:22:22.689521 140097193137984 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0729 07:22:22.690659 140097193137984 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0729 07:22:23.870742 140097193137984 deprecation_wrapper.py:119] From /home/aily/py3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# 2,337 texts collected.
# Training new model w/ 2-layer, 128-cell Bidirectional LSTMs
# Training on 77,079 character sequences.
# W0729 07:22:27.708454 140097193137984 deprecation.py:323] From /home/aily/py3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/30
# 602/602 [==============================] - 140s 233ms/step - loss: 4.2917
# ####################
# Temperature: 0.2
# ####################
# 外观和内饰，外观，内饰精致
#
# 外观和内饰，外观，内饰，内饰精致，这个价格的地方
#
# 外观和内饰，内饰精致，动力强劲，操控性价比
#
# ####################
# Temperature: 0.5
# ####################
# 外观和内饰，内饰精致，中控好，还是不错的感觉很好用，动力强劲，在车子的前一个刹车，这个价格也是外观，本对于开来的动力，比较低，但是一点是一点，那种驾驶感觉，这是一个人的地方，
#
# 奔驰的品牌
#
# 外观和内饰，这个价格高，让人比较高，这个价位的车子，但是一比外观也不说了。
#
# ####################
# Temperature: 1.0
# ####################
# 最的品牌
#
# 程可比，国论个价格面车子科技感感
#
# 最品牌
#
# Epoch 2/30
# 602/602 [==============================] - 148s 245ms/step - loss: 3.0274
# ####################
# Temperature: 0.2
# ####################
# 外观漂亮，内饰豪华，品牌
#
# 外观漂亮，内饰精致，内饰豪华，同级别车中数一代的品牌。
#
# 外观漂亮，内饰漂亮，品牌
#
# ####################
# Temperature: 0.5
# ####################
# 外观内饰都很漂亮，动力很好
#
# 外观漂亮，内饰精致科技配置丰富，动力很强，隔音效果真的不错。
#
# 内饰做工精致
#
# ####################
# Temperature: 1.0
# ####################
# 奔驰做工精致，将人想的虚荣心
#
# 车的秒杀内工艺颜值和同级车里面同级别的话那款式有科技
#
# 外观，回头率高了多说也是冲要的大方面那挺满意的
#
# Epoch 3/30
# 602/602 [==============================] - 145s 241ms/step - loss: 2.3105
# ####################
# Temperature: 0.2
# ####################
# 外观和内饰，同级别车里面最好的，外观也很漂亮，我看他迷人的感觉，内饰也绝对是我最满意的，如果说最满意的一点就是“内饰。
#
# 外观和内饰，同级别的车型，没有任何的短板，内饰做工精细，奔驰的做工出众，高端大气上档次。
#
# 外观和内饰，真的是太漂亮了，内饰也是我最满意的，一个档次。
#
# ####################
# Temperature: 0.5
# ####################
# 奔驰的品牌，操控还是比较不错，高速超车的时候很稳，开起来很舒服，坐舒适性感
#
# 最满意的应该是外观和内饰，真的属于最满意的地方，外观也很漂亮，不是盖的。
#
# 外观和内饰，空间，动力，行车灯，日行灯很好看，座椅舒适度很好，高速巡航和限速巡航，方向盘的，还可以说的加速
#
# ####################
# Temperature: 1.0
# ####################
# 性价比比较好，奔驰是外观时尚，操控灵活，高速四撞一一直0判断车.一次大的阻既能可惜内味道乡奔驰C级的从更是知道上也能中数一二的优点
#
# 同级别无敌车头很大，内饰做工精细，这是动力。
#
# 空间很大爱，音效还是优雅。
#
# Epoch 4/30
# 602/602 [==============================] - 148s 246ms/step - loss: 1.7499
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力，都是相当不错的选择。
#
# 外观，内饰，动力，都满意
#
# 外观，内饰，动力，都满意
#
# ####################
# Temperature: 0.5
# ####################
# 外观和内饰，相当不错的选择。
#
# 内饰，动力都不错，动力也足。
#
# 外观，内饰，特别是中控，还有那个智能互联，自己非常方便，舒适性很好，舒适性好，油耗也不错。
#
# ####################
# Temperature: 1.0
# ####################
# 内饰太漂亮，精致标显档次，智能大灯很智能，很智能，什么都用，乘坐在车内刹停车都是在享生生活，享受驾驶感一流，所有需要说很多，但是外观设计也是内饰的霸细，发动机什么的小了！
#
# 驾驶舒适型很好，操控好，比高速稍微加速兼加速性能模式等到发动机运动。方向很轻松。
#
# 内饰同级别
#
# Epoch 5/30
# 351/602 [================>.............] - ETA: 55s - loss: 1.3182
