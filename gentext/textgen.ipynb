# %%
from textgenrnn import textgenrnn
# Out:
# Using TensorFlow backend.
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ##### 配置

# %%
config = {
        'rnn_layers': 6,
        'rnn_size': 128,
        'rnn_bidirectional': False,
        'max_length': 15,
        'max_words': 1000,
        'dim_embeddings': 100,
        'word_level': False,
        'single_text': False
    }

# %% [markdown]
# ##### 训练模型

# %%
textgen = textgenrnn(name="car")                   # 给模型起个名字，比如`my.poem`, 之后生成的模型文件都会以这个名字为前缀
textgen.reset()                                         # 重置模型
textgen.train_from_file(                                # 从数据文件训练模型
    file_path = '/home/aily/traindata/textgen/data.txt',  # 文件路径
    new_model = True,                                   # 训练新模型
    num_epochs = 30,                                    # 训练轮数
    word_level = False,                                 # True:词级别，False:字级别
    rnn_bidirectional = True,                           # 是否使用Bi-LSTM
    max_length = 25,                                    # 一条数据的最大长度
)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0818 22:26:33.979153 139735730042688 deprecation_wrapper.py:119] From /home/aily/env/py36/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0818 22:26:33.984271 139735730042688 deprecation_wrapper.py:119] From /home/aily/env/py36/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0818 22:26:34.002992 139735730042688 deprecation_wrapper.py:119] From /home/aily/env/py36/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0818 22:26:34.004149 139735730042688 deprecation_wrapper.py:119] From /home/aily/env/py36/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0818 22:26:34.005227 139735730042688 deprecation_wrapper.py:119] From /home/aily/env/py36/py36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0818 22:26:38.102687 139735730042688 deprecation_wrapper.py:119] From /home/aily/env/py36/py36/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# 2,337 texts collected.
# Training new model w/ 2-layer, 128-cell Bidirectional LSTMs
# W0818 22:26:39.626538 139735730042688 deprecation.py:323] From /home/aily/env/py36/py36/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Training on 77,079 character sequences.
# Epoch 1/30
# 602/602 [==============================] - 14s 22ms/step - loss: 5.4790
# ####################
# Temperature: 0.2
# ####################
# 内饰，外观，内饰，动力，内饰，动力，内饰，内华，动力，动力，动机车的一的是车车不很，车车是车是然是一上，车车车的，动机，车但是动力很好
#
# 内饰，外观，内饰，动力，内饰，动力，动力，车的是车的就，动力，车车车车车车是是动力，车车车车的是动力，不0较，动力，动力，动力的是车人，动机，车的是车车，动力，车车的很好，车，车的的车驶一，然是车的是动力
#
# 外观，内饰控，外观，外观，内饰，动力，车车车的是车驶
#
# ####################
# Temperature: 0.5
# ####################
# 内饰，动力，动力，然比速，内饰，内华
#
# 外观，外观，车宝0公错，漂服
#
# 内饰控也精致，外观，车的是人好，内华同级是内华的感了
#
# ####################
# Temperature: 1.0
# ####################
# 扎好的比全，同价动雅，然是安其这音精间内华，样非常对天满意、不听也，感现速地实是不需驾最后
#
# 动力硬感S疲都和外提级，降
#
# 外观C速回可驶代挡。不
#
# Epoch 2/30
# 602/602 [==============================] - 10s 16ms/step - loss: 4.2991
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰
#
# 外形和内饰，外形，内饰，内饰，内饰，内饰。
#
# 外观，内饰，内饰精致，内饰
#
# ####################
# Temperature: 0.5
# ####################
# 外形，外形，操控性，内饰精致，做工精致
#
# 外形，外形，操控性好，内饰。
#
# 外形，内饰精致。
#
# ####################
# Temperature: 1.0
# ####################
# 动间不较自己油耗功盘轮然说包沛。
#
# 内饰非常有子
#
# 当然是内饰价比说也要丽都很好，底盘能有质位和吸的韧次，操控够在选O过下氛高很的，小向杆及发动也起都给力。
#
# Epoch 3/30
# 602/602 [==============================] - 10s 17ms/step - loss: 3.4086
# ####################
# Temperature: 0.2
# ####################
# 外观时尚，内饰，动力强，内饰，舒适性，操控性能也是不错的
#
# 内饰，外观，内饰，动力强，内饰，操控性能很大气。
#
# 外观，内饰，操控性好，动力强。
#
# ####################
# Temperature: 0.5
# ####################
# 外观，内饰，外观很精致，内饰，操控，操控也很好，装踩了
#
# 外观很好，内饰
#
# 最满意的地方向盘上都很多，外观和内饰，动力强，操控也很好。
#
# ####################
# Temperature: 1.0
# ####################
# 油耗，内饰，人色奔驰的车的地方能了。
#
# 最满意很个为老是有最满意，不前一镜奔驰的身里里在内就是很高。最高N上就是只是让人感觉，有面颖的3三么，感觉所理了。动力和还有c人提550T 我有 品意，品牌格 我上起果三老耳便现说 与空间可以完全操控亮、舒适性，蓝你素牌也是安全水性精到影还棒。
#
# 内饰很实用！流舒适好用。
#
# Epoch 4/30
# 602/602 [==============================] - 10s 16ms/step - loss: 2.7593
# ####################
# Temperature: 0.2
# ####################
# 外观和内饰，外观是奔驰的车的内饰，最喜欢的地盘的，内饰是真的的C了的地方面的地方，我满满天生的想控还是不是自动泊的，不是同级别的同级别一台神，还有大家已丝，不错一次的那个一点的科技感也在没重的，不要来就是选的地精越的。
#
# 外观和内饰，外观是内饰，最满意的地方，内饰也是最满意的地项的选的，不是同级别的设计的，最终别最满意的就是就是我觉引的就是稳。
#
# 外观和内饰，外观很棒，内饰，内饰，动力也是内饰，还是最好的，最喜欢品挡的的，优点，很有的就是跨级别的就是给人的。外观漂亮，各方向盘很多，各方面的重都是不是我产的的时候也是享受的，可以，享受驾驶来就是不是比较体面的前条，不会开的短，各动力，但是那个的感觉，不错，毕因为开了本车生活，享受起来的。。
#
# ####################
# Temperature: 0.5
# ####################
# 外观和内饰，奔驰的品牌的，内饰一流
#
# 外观内饰
#
# 内饰做工精致，外观及内饰，高达，舒适感觉就是奔驰的（操控对吧！
#
# ####################
# Temperature: 1.0
# ####################
# 动力够，这么说预妹物提格特别没%看了
#
# 安全，设计漂亮
#
# 外观外观很漂亮
#
# Epoch 5/30
# 602/602 [==============================] - 10s 17ms/step - loss: 2.2671
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力强劲。
#
# 外观，内饰豪华，动力强劲，操控，操控一流。
#
# 外观，内饰
#
# ####################
# Temperature: 0.5
# ####################
# 外观，内饰豪华的豪华，动力，操控、操控、内饰，精致，做工真的特别是换白都很舒服，性能手要的要很高
#
# 外观，内饰，外观（外观是最满意的地方，内饰是最满意的，内饰，外观也不厌，内饰，用料活，看到内无打奔驰的进一个车档次，开车的感觉。内饰是在一点到，叭体在那么上手。a4V她！在品牌，这个人的在在座坏，这两当家家轴驱车的化。虽然是很有没有于第两天籁,标中控非常不错，回头头级够了。
#
# 外观，内饰，同级别最好的，操控一流。。。内饰。
#
# ####################
# Temperature: 1.0
# ####################
# 操控性好，还是相比于的档次，超人手，比较帅当满意的也比较也没大心目没街，别养的（更是年较低，那个段面高的互联爱.优种感惊耳
#
# 方向盘厉重的，外观是理的座椅土科技手。其族前脸哒，全系想多尽些时的柔保保里套之带累,累，关，总以前才的飘上90保p4级次又非常丰富多很主型很敞的发呵。
#
# 操控一大品牌知，外观很漂亮，内饰很吸得的。比较刹越上手优型以能太好看.。
#
# Epoch 6/30
# 602/602 [==============================] - 10s 17ms/step - loss: 1.8810
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，内饰，动力，动力足，动力、内饰，做工精致，看到小，优雅好，做工不错，做得非常不同级，最后车子很有做的？内饰非常方便，操控表一看超
#
# 内饰，外观，内饰，动力，动力、内饰、做工精致，做工是级别C级的车级的做的平衡了，是奔驰，最后大次一个人喜欢，能太为一代，最满足一个档次，外观
#
# 外观，内饰，外观，内饰
#
# ####################
# Temperature: 0.5
# ####################
# 内饰（我的内饰，奔驰的起位有豪华，奔驰的动力、做的
#
# 外观，内饰非常不用说了！
#
# 内饰做工，多称配置很高，车辆车很不错
#
# ####################
# Temperature: 1.0
# ####################
# 最满意的就是无可庸蓝，奔驰品牌、动力 你一眼，巴日行次被还算真当实
#
# 车辆级别一个来的外红色无可挑剔！
#
# 提车到现在3万公里无敌的新了然发现什么的暴力！
#
# Epoch 7/30
# 602/602 [==============================] - 10s 16ms/step - loss: 1.5807
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，品牌
#
# 外观和内饰，当时第一眼就喜欢
#
# 外观和内饰，相对手高
#
# ####################
# Temperature: 0.5
# ####################
# 内饰完美
#
# 外观，内饰，用料都很好，智能大灯，用真心喜欢。
#
# 外观，内饰，品牌
#
# ####################
# Temperature: 1.0
# ####################
# 车的豪华感油耗很大灯
#
# ,外观和内饰才是入系好看，但是它车代面都是奔驰的
#
# 加速快，提速反动力。
#
# Epoch 8/30
# 602/602 [==============================] - 10s 16ms/step - loss: 1.3379
# ####################
# Temperature: 0.2
# ####################
# 外观和内饰，动力也满意
#
# 外观，内饰
#
# 外观内饰，动力也满意
#
# ####################
# Temperature: 0.5
# ####################
# 内饰和外观和内饰，前脸，空间也是最好的之后后期，空间也是最然是比较的就是而。其别是宝马了，所以但是及外观也我会不较不是于宝马的，还是提后也是看色，但不是比较油于一担的。内饰就是最满意的，外观与当足有奔驰的品牌也比以没道之后置也比较实，还有得奥迪。
#
# 大标，外观，内饰。
#
# 外观，内饰，动力也满意
#
# ####################
# Temperature: 1.0
# ####################
# 各方面整体豪华感，动力都体子，性价比很高
#
# 外观，内饰，高端高科技高。
#
# 本无疑要上奔驰品牌的入门级，尤其是S级的之后款的了
#
# Epoch 9/30
# 602/602 [==============================] - 10s 17ms/step - loss: 1.1435
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精致，用料都很扎实，也很赞。轻轻运动。
#
# 外观，内饰
#
# 外观内饰，动力也是不愧是奔驰，比宝马3系和3系a4足，比较息的乞足高档，一点在在内饰做工以内工以为来有什么的不致个看中的感了，优点就是很大奔驰级，美点，原因就是最满意的的，内饰的是不多。
#
# ####################
# Temperature: 0.5
# ####################
# 外观和内饰，太漂亮了，开了一点也喜欢
#
# 外观，内饰，动力 外观，内饰做工，舒适体高内的车档，包他的流容，一些设计很实用，可以有晕的内饰，我优爆小，可以（但是很优细，比较丰行的做工艺，操控性能说指便，很不错，开起来还可以优系景适，都很满意，
#
# 外观，内饰
#
# ####################
# Temperature: 1.0
# ####################
# 安全配置很高，LED性都精致，骚车很好，使合2000以就是宝马3系性
#
# 的内饰做工达到氛分，这次看买车太多人都眼该能真的真的美，刹级车年轻上奥迪。在同级别前也方便时了的很适！
#
# 车身脸，它朋友都特爱.
#
# Epoch 10/30
# 602/602 [==============================] - 10s 16ms/step - loss: 0.9918
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，大标，动力，都是最好，操控、舒适
#
# 外观和内饰，相对于同级别车型，这个品牌
#
# 外观和内饰，动力也是最好，操控感受。而且同级别豪华专。完全辅助的还有宝马迟。
#
# ####################
# Temperature: 0.5
# ####################
# 外观和内饰，真心喜欢，眼球，其次就看看就接上这个档次。开车大的驾驶和这个都会就没有也不错。
#
# 外观，内饰，动力也满意。
#
# 外观好看，内饰漂亮，内饰豪华，用料都很精致
#
# ####################
# Temperature: 1.0
# ####################
# 巴适。
#
# 底盘，安全性能强、操控、操控、做工精细，油耗效明非常好。
#
# 奔驰的做工，虽然后排空间。
#
# Epoch 11/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.8672
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力也满意。
#
# 外观，内饰，动力，转向半径小，转向轻盈，操控性能，同级别的价格的内饰感了再的，感觉精致的L来，这个在一种把因在奔驰的小内饰很给力，因是大办重人喜欢，却比之前，同排气于操控好，超车也是操控，自动买奥迪
#
# 外观，内饰，动力，转向半径小，转向轻盈，操控性能，同级别的操控都是最好的
#
# ####################
# Temperature: 0.5
# ####################
# 外观，内饰
#
# 外观，内饰
#
# 外观，内饰，动力，动力，转向半径比很多。
#
# ####################
# Temperature: 1.0
# ####################
# 整车大出给力，外观内饰去第一眼。。
#
# 外观漂亮，内饰精致
#
# 内饰非常完美，中控确实的梦。。另方向盘很智能手，还成840。动力了在刹的标。动力自动过，内饰也很好。内香车灯。
#
# Epoch 12/30
# 602/602 [==============================] - 10s 16ms/step - loss: 0.7627
# ####################
# Temperature: 0.2
# ####################
# 外观和内饰
#
# 外观和内饰
#
# 外观，内饰
#
# ####################
# Temperature: 0.5
# ####################
# 外观，内饰
#
# 外观和内饰在BBA里面座椅程朋友喜欢，知道特别是我好看。我不能和奔驰
#
# 内饰和外观，动力也很不错
#
# ####################
# Temperature: 1.0
# ####################
# 外观
#
# 车很车型低调比较高，外观漂亮，内饰做工精细
#
# 内饰精致，动力充沛。车很好
#
# Epoch 13/30
# 602/602 [==============================] - 10s 16ms/step - loss: 0.6753
# ####################
# Temperature: 0.2
# ####################
# 内饰做工精细，如果座椅用真皮，皮质感满意
#
# 外观，内饰，前脸
#
# 外观，内饰，前脸，侧身腰线。
#
# ####################
# Temperature: 0.5
# ####################
# 外观和内饰
#
# 外观和内饰，最满意的地方，我就是选择了这台车还有一个内饰，比以能吸高型就是外观大比合去，做到使候的表现，如果我不喜欢
#
# 内饰做工精致。
#
# ####################
# Temperature: 1.0
# ####################
# 舒适性在手量我都很不错。
#
# 大气的内饰，最靓丽，看着舒服
#
# 驾驶感受好轮朗
#
# Epoch 14/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.6058
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力也满意。而且倒车镜带自动折叠。
#
# 外观，内饰，动力也满意。而且倒车镜带自动折叠。
#
# 外观，内饰，动力也满意。
#
# ####################
# Temperature: 0.5
# ####################
# 外观，外观，内饰，中最好，隔音好，适合发动机会起来求，但是还是很不觉得此的选车子。
#
# 内饰做工，虽然没有和太多车子比较过，但是奔驰的内饰真的是最简单却又是最细致的，没有太多复么也增了一般来都是外观，外观我上所有被名是座，车子年能明三因交的也是外观也是我大家买的一流。
#
# 外观真心喜欢，大标很霸道
#
# ####################
# Temperature: 1.0
# ####################
# 驾炫喜欢外观
#
# 并特别是居长轴松米色其他，全景天窗。
#
# 好看，外观是我最豪华的内饰都很爽，自动技感和动力够，做工很用，奔驰这就是宝马3，没好的奔驰的档次话车的，虽然一点是从是好看新奔驰的相信的大奔奥真的大大，要面标的内饰，各随足得心完致，同级把车很适度比较方向，立车是买了踩。
#
# Epoch 15/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.5464
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，空间，都满意
#
# 外观，内饰，动力，都满意
#
# 外观，内饰，空间，都满意
#
# ####################
# Temperature: 0.5
# ####################
# 外观大气，行驶动力充沛，动力充沛。车子的A4
#
# 内饰做工精细，如果座椅用真皮，皮质细腻点的话那内饰就完美了！
#
# 内饰做工和质量。
#
# ####################
# Temperature: 1.0
# ####################
# 内饰漂亮，品质十响尽金属质感的车头，后驱车子也还是很豪华的低子而后好。一般发动常大周，后排各刹车车很车直接非常小从。
#
# 后驱车操控性价比
#
# 高端、认安技
#
# Epoch 16/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.4941
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，空间，都满意
#
# 外观，内饰，空间，都满意
#
# 外观，内饰，品牌
#
# ####################
# Temperature: 0.5
# ####################
# 动力还可以，家用完全够用，底盘，发动机是奔驰的内饰，标也可能太眼也不错，一样水，相豪华不可我，比同级然控可能不会等，无钥配置不外车日要重几个人比较特别足！
#
# 内饰，还是内饰
#
# 外观，内饰，品牌，油耗都是非常好。
#
# ####################
# Temperature: 1.0
# ####################
# 大奔小做工精细，有内外安全一流。车内的中控非常精致把到实就是奔驰C级别是操控够有的精致，有档次，灯也是不是疝了，用题红过，满意，更是以免奔驰的市区发动车环方，体感围本用平10200-效果不用明ho，静音感觉，在时色心提高功着就不接噪，音空力够用，车多感觉得就是满足了！
#
# 外观不用多说了，小S嘛。新C的内饰很豪华，不管是驾驶室或者后座，用手触摸得到，比同级别的科老白车的身提驶其实实一气款是一流。这个本看都没想。但漂亮MM很有大气的表发型能够有地种80奔驰，有档次，只是这个什么很好很年久，跟颜提车了，开了我最满意的选择低。原因车平车了发然有1角吧！感觉我是那线的氛觉好，C250提接足，c级内用老备，因为还是C小过的质感过大当满意，毕个小要的号，就是日奔驰的脸是一个动大了。
#
# 当然是性价比。奔驰估计是所有人儿时的梦想吧，之前想都没想过，优惠10万的价格拿下时尚版。该有的都有了。每次启动的时候大灯上下左右晃动自检的时候就有种莫名优越感。同样价格的配置相对宝马和奥迪要高很多。
#
# Epoch 17/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.4504
# ####################
# Temperature: 0.2
# ####################
# 外观内饰
#
# 外观内饰
#
# 外观内饰
#
# ####################
# Temperature: 0.5
# ####################
# 外观和内饰，外观流线行很棒，特别是全LED的大灯点亮之后非常有科技感，低配上面的大灯好像和高配不一样。
#
# 外观，内饰。有号称小S，年轻人稳重。
#
# 内饰，外观
#
# ####################
# Temperature: 1.0
# ####################
# C前的车给我的优点么，相信提速感很好
#
# 外观
#
# 后排座椅大，材在的腰线很顺悬挂不失材都是一论都让人心能也是做工，比直有质运动，汽车小现，各也10-小里得的8系跑，但打后服随装，但着后段前玻，以前过。加速快综合应力控配坐，赞转门，我开很有感觉，一切个直4厚奔、
#
# Epoch 18/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.4139
# ####################
# Temperature: 0.2
# ####################
# 外观内饰很有感觉，逼格高
#
# 外观和内饰，外观流线行很棒，特别是全LED的大灯点亮之后非常有科技感，低配上面的大灯好像和高配不一样。
#
# 外观和内饰，太漂亮了
#
# ####################
# Temperature: 0.5
# ####################
# 外观大气漂亮，内饰精美同级别最佳，品牌底蕴深厚，有面子
#
# 外观优雅 内饰温馨 动力十分强进 超车没问题
#
# 外观时尚，内饰豪华，高科技配置很到位，很人性化
#
# ####################
# Temperature: 1.0
# ####################
# 品牌，各精致操控一流.MMed，车内饰。
#
# 外观好看，内饰不错，这个品牌，绝对的虚荣油也很好，
#
# 做工一流。品牌
#
# Epoch 19/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.3830
# ####################
# Temperature: 0.2
# ####################
# 外观和内饰，外观！重要的事说三遍！！！那小逼格绝对让人家一样之完了还用料方面那也是绝对够用的！那小人：小上了。！，所以车档次，后然绝对在跟不会因后几，感觉很喜欢。！！也大奔的外观最满意的就是很舒适，特别喜欢我的感显。
#
# 外观和内饰
#
# 外观和内饰，还有蓝牙电话不错，我一般电话很多，这样安全多了。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰，外观
#
# 外观，内饰
#
# 外观和内饰
#
# ####################
# Temperature: 1.0
# ####################
# 外形，
#
# 动力还可以，家用完全够了
#
# 风骚的动力
#
# Epoch 20/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.3577
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力，转向都很棒
#
# 外观，内饰，动力，操控。
#
# 外观和内饰
#
# ####################
# Temperature: 0.5
# ####################
# 外观，内饰，动力，品牌
#
# 外观，内饰，动力，转向都很棒
#
# 品牌，外观，线条流畅。
#
# ####################
# Temperature: 1.0
# ####################
# 外观，后驱，动力不错，内饰还行，动力绝对在奔驰，不同，就是怕好的话用全天牌车的设计非常好用。还有优热能一算要调大松大的
#
# autohold功能市区使用十分方便。
#
# 家用空间够大. 内饰精致 舒适度也很好
#
# Epoch 21/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.3306
# ####################
# Temperature: 0.2
# ####################
# 内饰做工，虽然没有和太多车子比较过，但是奔驰的内饰真的是最简单却又是最细致的，没有太多复杂的按键，不需要花太多时间研究，所有按键的阻尼感都正正好好
#
# 外观和内饰，赞
#
# 外观，内饰。操控灵活
#
# ####################
# Temperature: 0.5
# ####################
# 外观很喜欢，内饰设计漂亮，做工优良，保持上这车子
#
# 动力强劲，操作轻便！
#
# 内饰和外观吧
#
# ####################
# Temperature: 1.0
# ####################
# 内饰做工
#
# 颜值爆表，回头率很奔驰是品牌，品质，内饰，安静。
#
# 动力充沛，内饰精致有
#
# Epoch 22/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.3139
# ####################
# Temperature: 0.2
# ####################
# 外观和内饰，动力也满意。而且倒车镜带自动折叠。
#
# 外观和内饰，动力也满意。而且倒车镜带自动折叠。
#
# 外观和内饰，还有蓝牙电话不错，我一般电话很多，这样安全多了。
#
# ####################
# Temperature: 0.5
# ####################
# 动力很好，谁说奔驰的车身比较时尚，有力好看，系合现星，各比迷人就不之后的车子比较边点，但买节几点也不大了一点是旧了。外观是银色车体外观，第一位，一足。个里快，排一花了，天简直舒适性
#
# 外观，内饰，动力，转向都很棒
#
# 外观内饰，同级别最好的车型时尚
#
# ####################
# Temperature: 1.0
# ####################
# 外观，内饰，功能都很喜欢！
#
# 感觉车很结实,比前面开的迈腾结实觉能多系C200。腾去。多完心也有等价钱等不了一敲开灵,100年的车的了。
#
# 内饰非常满意，很有质感
#
# Epoch 23/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.2970
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，空间，都满意
#
# 外观，内饰，空间，都满意
#
# 外观，内饰，空间，都满意
#
# ####################
# Temperature: 0.5
# ####################
# 外观很满意，内饰精美，有内涵
#
# 内饰，外观，悬架支撑到位。
#
# 外观，内饰，空间，都满意
#
# ####################
# Temperature: 1.0
# ####################
# 红灯加速甩其他车一大截。
#
# 内饰漂亮，外观无敌
#
# 大气身好看，空间优美
#
# Epoch 24/30
# 602/602 [==============================] - 10s 17ms/step - loss: 0.2844
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力，转向都很棒
#
# 外观，内饰，动力 都喜欢死了没法排序
#
# 外观和内饰都很漂亮，完胜宝马三系和奥迪A4
#
# ####################
# Temperature: 0.5
# ####################
# 外观，内饰，毕竟是新一代的c级，外观内饰都是全新的改变，优美的车身流线，漂亮的全LED灯，内饰双缝线纤维皮，高档的中控布局，但是屏幕边框太粗，外观屁股部分太窄小。
#
# 外观和内饰，还有蓝牙电话不错，我一般电话很多，这样安全多了。
#
# 外观内饰设计
#
# ####################
# Temperature: 1.0
# ####################
# 外观就是奔驰啊。220时，内饰风，一点说品牌看的。等8，各不用说了开过手，而且.以得了就是撩跟一内饰：买车前级候会花位，无品牌用简比较，非常关下的。
#
# 做工精致
#
# 内饰不错.操控性不错.喜欢后很好
#
# Epoch 25/30
# 602/602 [==============================] - 10s 16ms/step - loss: 0.2733
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，空间，都满意
#
# 外观和内饰，还有蓝牙电话不错，我一般电话很多，这样安全多了。
#
# 外观，内饰，空间，都满意
#
# ####################
# Temperature: 0.5
# ####################
# 外观漂亮，内饰高大上，很有质感，很喜欢车内的按键，金属质感特别好。天窗很大很透亮，打开天窗盖板感觉很好，没有任何压抑感。
#
# 内饰很有外观外观，看惯了新C的内饰，无敌了，很大标，大灯和3内饰是够不错。
#
# 外观和内饰，赞
#
# ####################
# Temperature: 1.0
# ####################
# 加速能力与操控性能，虽然涡轮有半秒的延迟，但是日常使用中的直线加速能力可圈可点，可拼杀任何30万以内的车型，操控一流，较高的悬挂韧性同时保持足够的舒适度
#
# 酷炫的外形非常漂亮，年轻时尚,
#
# 大标，外观新颖，给人的感觉操控很精致
#
# Epoch 26/30
# 602/602 [==============================] - 10s 16ms/step - loss: 0.2643
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力，转向都很棒
#
# 外观内饰
#
# 内饰，外观，悬架支撑到位。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰精致，科技含量高。
#
# 外观，内饰，空间，都满意
#
# 内饰，动力也还可以
#
# ####################
# Temperature: 1.0
# ####################
# 品牌综合性能很好，底盘扎实，悬挂很好
#
# 动力、操控、底盘，舒适性吧
#
# 外观看着都觉得爽，行驶质感不错，内饰做工很精细，动力够用，操控精准
#
# Epoch 27/30
# 602/602 [==============================] - 10s 16ms/step - loss: 0.2558
# ####################
# Temperature: 0.2
# ####################
# 内饰做工非常满意
#
# 外观内饰同级别无人能敌。
#
# 外观内饰
#
# ####################
# Temperature: 0.5
# ####################
# 动力，底盘，方向盘质感
#
# 外观大气，配置高，动力强劲。
#
# 内饰做工非常出色，坐到里面，感觉奔驰的气质是别的品牌不可比拟的。
#
# ####################
# Temperature: 1.0
# ####################
# 必须是奔驰的内饰以及外观 操控也是非常满意的一点，总之买了从来就没后悔一丝丝 ！
#
# 智能大灯，动力120以后还能随叫随到。轻松140。
#
# 中控漂亮，做工精致，用料都很好，智能最！！实！
#
# Epoch 28/30
# 602/602 [==============================] - 10s 16ms/step - loss: 0.2484
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力，操控。同价位简直无敌啦。
#
# 外观，内饰，动力，操控。同价位简直无敌啦。
#
# 外观和内饰，外观流线行很棒，特别是全LED的大灯点亮之后非常有科技感，低配上面的大灯好像和高配不一样。
#
# ####################
# Temperature: 0.5
# ####################
# 外观和内饰，还有蓝牙电话不错，我一般电话很多，这样安全多了。
#
# 内饰做工和配置比宝马3系要强好多。大爱三幅方向盘。
#
# 最满意的必须是C200的设计了，无论是外观，还是内饰的设计都很帅！买车的原因也是奔着设计来的；
#
# ####################
# Temperature: 1.0
# ####################
# 外形动感，线条饱满，比例协调，大牌时尚。
#
# 外观内饰
#
# 外观内饰
#
# Epoch 29/30
# 602/602 [==============================] - 10s 16ms/step - loss: 0.2417
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力，操控。同价位简直无敌啦。
#
# 外观和内饰，动力也满意。而且倒车镜带自动折叠。
#
# 外观，内饰，动力，操控。同价位简直无敌啦。
#
# ####################
# Temperature: 0.5
# ####################
# 内饰，动力也还可以
#
# 外观漂亮 底盘扎实 操控敏捷 安全性高
#
# 外观和内饰，动力也满意。而且倒车镜带自动折叠。
#
# ####################
# Temperature: 1.0
# ####################
# 内饰好看..特爱米色..舒适度很好.比阿特兹强了n个档次.
#
# 外观
#
# 品牌好，价格低，做工棒，动力足
#
# Epoch 30/30
# 602/602 [==============================] - 10s 16ms/step - loss: 0.2353
# ####################
# Temperature: 0.2
# ####################
# 外观，内饰，动力，转向都很棒
#
# 外观，内饰，动力，转向都很棒
#
# 外观，内饰，动力，转向都很棒
#
# ####################
# Temperature: 0.5
# ####################
# 外观，内饰，动力，转向都很棒
#
# 外观和内饰，还有蓝牙电话不错，我一般电话很多，这样安全多了。
#
# 外观好看，内饰漂亮，30w左右车身价，这个车子比较适合年轻人开
#
# ####################
# Temperature: 1.0
# ####################
# 外观内饰设计
#
# 外形，灯光，内饰细节；
#
# 外观，高端悬挂非常稳，中网大标内饰非常棒

# %% [markdown]
# ##### 生成数据

# %%
textgen = textgenrnn(
  name="car",
  weights_path='./car_weights.hdf5',
  config_path='./car_config.json',
  vocab_path='./car_vocab.json'
)
textgen.generate(20, temperature=1.0)
# Out:
#  15%|█▌        | 3/20 [00:00<00:03,  5.47it/s]
# 内饰，品质，就喜欢奔驰这个品牌
#
# 17款的车内饰座椅红色翻毛皮哦！这才是我最爱的
#
#
#
# 内饰非常满意，很有质感
#  30%|███       | 6/20 [00:00<00:02,  6.65it/s]
# 绚丽的立标外观，迷离的多条式轮圈，黑色的车身线条，光看前脸，回头率比较高哦。
#  35%|███▌      | 7/20 [00:00<00:02,  4.75it/s]
# 就是感觉车子的外观实在是很够好，我说的地方，同级别梦坐来都有是别可以那个B中地方盘，定提长配置特别大奔驰是挺不是过的真心也不错，太高，4s店影行的
#  45%|████▌     | 9/20 [00:01<00:02,  4.36it/s]
# 一定是外观和内饰这是最吸引我的地方，每当去车库准备开车的时候看着它静静的停在那就有种驾驶的欲望，整个车身和线条都非常完美，白天再加上日间行车灯走着路上回头率还是挺高的。
#
# 性价比高，外观内饰做工精良，豪华感很好。
#  65%|██████▌   | 13/20 [00:01<00:01,  5.06it/s]
# 如果非要给我的C180L“满意点”排名的话：1、内饰；2、奔驰品牌美誉度和知名度、很现、外观念空常棒，做工不非常档。
#
# 外观和内饰
#
# 外观和操控，逼格不用说了
#
# 加速性能优越，跑高速那是稳稳滴！
#
# 外观漂亮，内饰豪华，全景天窗超赞
#  85%|████████▌ | 17/20 [00:02<00:00,  5.55it/s]
# 满意的地方很多，比如外观和内饰，最满意的一点就是hold功能，遇红灯深踩一脚刹车，然后就什么都不用管了，灯一变给油就走。在堵车成为常态的市区道路上行车，这个功能简直是太方便了。应该给发明hold的设计师颁发重奖。
#
# 内饰改进比老款漂亮多了。
#
# 综合能力相当不错。
#
# 内饰漂亮精致
#
# 品牌底蕴
# 100%|██████████| 20/20 [00:02<00:00,  7.02it/s]
# 最满意还是车外观 还有里面座椅包裹性好
