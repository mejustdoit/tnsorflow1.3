# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ##### 1. 模拟回归

# %%
# 生成100个随机点
x_data = np.random.rand(100)
y_data = x_data * 0.1 + 0.2

#构造一个线性模型
b = tf.Variable(0.)
k = tf.Variable(0.)
y = k * x_data + b

#二次损失
loss = tf.reduce_mean(tf.square(y_data - y))

#第一梯度下降优化器
optimizer = tf.train.GradientDescentOptimizer(0.2)
#最小化代价函数
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for step in range(2000):
        sess.run(train)
        if(step % 20 == 0):
            print(step, sess.run([k, b]))
# Out:
# 0 [0.054637987, 0.100433506]
# 20 [0.10410755, 0.19775544]
# 40 [0.102422565, 0.19867623]
# 60 [0.10142877, 0.19921929]
# 80 [0.10084267, 0.19953954]
# 100 [0.100496985, 0.19972843]
# 120 [0.10029312, 0.19983983]
# 140 [0.10017288, 0.19990553]
# 160 [0.100101955, 0.19994429]
# 180 [0.10006011, 0.19996715]
# 200 [0.10003546, 0.19998063]
# 220 [0.10002091, 0.19998857]
# 240 [0.10001233, 0.19999325]
# 260 [0.10000727, 0.19999602]
# 280 [0.10000429, 0.19999765]
# 300 [0.100002535, 0.19999862]
# 320 [0.10000149, 0.19999918]
# 340 [0.1000009, 0.19999951]
# 360 [0.10000052, 0.19999972]
# 380 [0.10000032, 0.19999982]
# 400 [0.100000195, 0.19999988]
# 420 [0.100000195, 0.19999988]
# 440 [0.100000195, 0.19999988]
# 460 [0.100000195, 0.19999988]
# 480 [0.100000195, 0.19999988]
# 500 [0.100000195, 0.19999988]
# 520 [0.100000195, 0.19999988]
# 540 [0.100000195, 0.19999988]
# 560 [0.100000195, 0.19999988]
# 580 [0.100000195, 0.19999988]
# 600 [0.100000195, 0.19999988]
# 620 [0.100000195, 0.19999988]
# 640 [0.100000195, 0.19999988]
# 660 [0.100000195, 0.19999988]
# 680 [0.100000195, 0.19999988]
# 700 [0.100000195, 0.19999988]
# 720 [0.100000195, 0.19999988]
# 740 [0.100000195, 0.19999988]
# 760 [0.100000195, 0.19999988]
# 780 [0.100000195, 0.19999988]
# 800 [0.100000195, 0.19999988]
# 820 [0.100000195, 0.19999988]
# 840 [0.100000195, 0.19999988]
# 860 [0.100000195, 0.19999988]
# 880 [0.100000195, 0.19999988]
# 900 [0.100000195, 0.19999988]
# 920 [0.100000195, 0.19999988]
# 940 [0.100000195, 0.19999988]
# 960 [0.100000195, 0.19999988]
# 980 [0.100000195, 0.19999988]
# 1000 [0.100000195, 0.19999988]
# 1020 [0.100000195, 0.19999988]
# 1040 [0.100000195, 0.19999988]
# 1060 [0.100000195, 0.19999988]
# 1080 [0.100000195, 0.19999988]
# 1100 [0.100000195, 0.19999988]
# 1120 [0.100000195, 0.19999988]
# 1140 [0.100000195, 0.19999988]
# 1160 [0.100000195, 0.19999988]
# 1180 [0.100000195, 0.19999988]
# 1200 [0.100000195, 0.19999988]
# 1220 [0.100000195, 0.19999988]
# 1240 [0.100000195, 0.19999988]
# 1260 [0.100000195, 0.19999988]
# 1280 [0.100000195, 0.19999988]
# 1300 [0.100000195, 0.19999988]
# 1320 [0.100000195, 0.19999988]
# 1340 [0.100000195, 0.19999988]
# 1360 [0.100000195, 0.19999988]
# 1380 [0.100000195, 0.19999988]
# 1400 [0.100000195, 0.19999988]
# 1420 [0.100000195, 0.19999988]
# 1440 [0.100000195, 0.19999988]
# 1460 [0.100000195, 0.19999988]
# 1480 [0.100000195, 0.19999988]
# 1500 [0.100000195, 0.19999988]
# 1520 [0.100000195, 0.19999988]
# 1540 [0.100000195, 0.19999988]
# 1560 [0.100000195, 0.19999988]
# 1580 [0.100000195, 0.19999988]
# 1600 [0.100000195, 0.19999988]
# 1620 [0.100000195, 0.19999988]
# 1640 [0.100000195, 0.19999988]
# 1660 [0.100000195, 0.19999988]
# 1680 [0.100000195, 0.19999988]
# 1700 [0.100000195, 0.19999988]
# 1720 [0.100000195, 0.19999988]
# 1740 [0.100000195, 0.19999988]
# 1760 [0.100000195, 0.19999988]
# 1780 [0.100000195, 0.19999988]
# 1800 [0.100000195, 0.19999988]
# 1820 [0.100000195, 0.19999988]
# 1840 [0.100000195, 0.19999988]
# 1860 [0.100000195, 0.19999988]
# 1880 [0.100000195, 0.19999988]
# 1900 [0.100000195, 0.19999988]
# 1920 [0.100000195, 0.19999988]
# 1940 [0.100000195, 0.19999988]
# 1960 [0.100000195, 0.19999988]
# 1980 [0.100000195, 0.19999988]
