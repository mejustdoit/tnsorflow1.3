# %% [markdown]
# ##  生成序列

# %%
import pandas as pd
import numpy as np
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
datas = pd.date_range('2014-02-01',periods=6)
datas
# Out:
# DatetimeIndex(['2014-02-01', '2014-02-02', '2014-02-03', '2014-02-04',
#                '2014-02-05', '2014-02-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),index=datas,columns=list('ABCD'))
df = df.sort_values(by='A')
df.head
df.tail
df.T
df
# Out:
#                    A         B         C         D
# 2014-02-04 -2.536202  0.232858 -0.800912  1.905372
# 2014-02-06 -1.770036  0.142608 -0.516244  0.799570
# 2014-02-03  0.193976 -0.155901 -2.096295  0.509431
# 2014-02-02  0.303217 -0.680292  1.238617  0.540799
# 2014-02-01  0.421723  0.166543 -0.212857 -1.016170
# 2014-02-05  0.725953 -1.486714 -0.569026  0.979297

# %% [markdown]
# ## python 绘图

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1,2,3])
plt.ylabel('some number')
plt.show()

# %%
import seaborn as sbn
import numpy as np
sbn.set(color_codes=True)
x = np.random.randn(100)
sbn.distplot(x)

# %%
from igraph import *
g = Graph([(0,1),(1,2),(2,3),(3,4),(4,2),(2,5),(5,0),(6,3),(5,6)])
g
summary(g)
g.degree()
from sklearn
# Out:
# IGRAPH U--- 7 9 --
# [2, 2, 4, 3, 2, 3, 2]

# %%
3/2
# Out:
# 1.5
